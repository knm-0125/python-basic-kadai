# %%
array = [
    "月曜日は曇りです",
    "火曜日は晴れです",
    "水曜日は曇り時々雨です",
    "木曜日は曇りです",
    "金曜日は晴れです",
    "土曜日は曇りのち雨です",
    "日曜日は雷雨です"
]
print(array[2])
# Out:
# 水曜日は曇り時々雨です

# %%
dictionary = {
    "mon": "曇り",
    "tue": "晴れ",
    "wed": "曇り",
    "thu": "曇り",
    "fri": "晴れ",
    "sat": "曇りのち雨",
    "sun": "雷雨"
}
print(dictionary["wed"])
# Out:
# 曇り
