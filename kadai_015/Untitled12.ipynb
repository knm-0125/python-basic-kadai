# %%
class Human:
    def __init__(self, name, age):
      self.name = name
      self.age = age

    def printinfo(self):
      print("名前:" + self.name)
      print("年齢:" + str(self.age))

person = Human("小波", 21)
person.printinfo()
# Out:
# 名前:小波
# 年齢:21
